# %%
# ===============================================================
#
#                         Tree Definition
#
# ===============================================================
class TreeNode:
    def __init__(self, attrName):
        self.attr = attrName
        self.son = dict()
        self.isLeaf = False
        self.leafLabel = None

    def getAttr(self):
        return self.attr

    def setAttr(self, attrName):
        self.attr = attrName

    def addSon(self, attrVal, subTree):
        self.son[attrVal] = subTree

    def getAllSon(self):
        return list(self.son.values())

    def getSonByAttrVal(self, attrVal):
        return self.son[attrVal]

    def getCurrentAttrDivision(self):
        return list(self.son.keys())

    def setLeaf(self, label):
        self.isLeaf = True
        self.leafLabel = label
        self.attr = str(label)


class Tree:
    def __init__(self, rootNode):
        self.root = rootNode

    def add(self, nextAttrName, currentVal):
        if self.root == None:
            print("warning: attempt to add a subtree to a null tree")
            return
        subTree = Tree(TreeNode(nextAttrName))
        self.root.addSon(currentVal, subTree)

    def printTree(self):
        if self.root == None:
            return
        if self.root.isLeaf:
            print("Reach Leaf:%s" % self.root.leafLabel)
            return
        print("Node %s has sons:" % (self.root.getAttr()))

        for subtree in self.root.getAllSon():
            if subtree.root == None:
                continue
            print(">" + subtree.root.getAttr())
        subtrees = self.root.getAllSon()
        for subtree in subtrees:
            subtree.printTree()
        if subtrees == []:
            print(">None")
        print("--------------")

    def deleteTree(self):
        self.root = None

# %%
# ===============================================================
#
#                         Construct Tree  v1
#
# ===============================================================
def gini(Dataset):
    labels = list(set(Dataset['label']))
    nrow = float(len(Dataset))

    def ratioSqr(label):
        return (float(sum(Dataset['label'] == label)) / nrow) ** 2

    giniVal = 1.0 - sum(map(ratioSqr, labels))
    return giniVal


def giniIndex(Dataset, attrName):
    giniIndexVal = 0.0
    nrow = float(len(Dataset))

    subDataset = Dataset[Dataset[attrName] == 0]
    nrowSub = float(len(subDataset))
    giniIndexVal += gini(subDataset) * nrowSub

    subDataset = Dataset[Dataset[attrName] == 1]
    nrowSub = float(len(subDataset))
    giniIndexVal += gini(subDataset) * nrowSub

    return giniIndexVal / nrow


def attrSelection(Dataset, Attributes, cheatMode=False):
    if cheatMode == True:
        Dataset = Dataset.sample(frac=0.3)

    def fucktion(attr):
        return giniIndex(Dataset, str(attr))

    optAttr = min(Attributes, key=fucktion)
    return optAttr

# =========================================================
# =========================================================

def identicalRows(df):
    for rowID in range(len(df) - 1):
        if not df.iloc[rowID, 1:].equals(df.iloc[rowID + 1, 1:]):
            return False
    return True


def treeGeneration(Dataset, Attributes):
    labels = train['label']

    # 1. 生成空节点node
    node = TreeNode(attrName="unset")
    # tree = Tree(rootNode=node)

    # 2. Boundary Case 1
    if len(set(labels)) == 1:  # 如果Dataset中的样本全属于同一类别C
        C = labels.iloc[0]
        node.sefLeaf(label=C)  # 将node标记成C类叶子节点
        tree = Tree(rootNode=node)
        return tree

    # 3. Boundary Case 2
    # 找到Dataset中样本数最多的类
    try:
        C = pd.Series.mode(labels)[0]
    except KeyError:
        C = labels.iloc[0]
    except IndexError:
        C = labels.iloc[0]

    if Attributes == [] or identicalRows(Dataset.iloc[:, Attributes]):  # 如果Attributes=∅,或者Dataset在Attributes的这几个属性上取值相同
        node.setLeaf(label=C)  # 将node标记成叶子节点，其类别是Dataset中样本数最多的类
        tree = Tree(rootNode=node)
        return tree

    # 3.5 pre剪枝 (myYY)
    if len(Dataset)<21:
        node.setLeaf(label=C)  # 将node标记成叶子节点，其类别是Dataset中样本数最多的类
        tree = Tree(rootNode=node)
        return tree

    # 4. 选择最优划分属性: optAttr
    t1=time.time()
    optAttr = attrSelection(Dataset, Attributes, cheatMode=False)
    t2=time.time()
    print("selected attr: %d,   size:%d, taking %f secs" % (optAttr, len(Dataset), t2-t1))
    sys.stdout.flush()
    node.setAttr(str(optAttr))

    # 5. 为optAttr属性的每一个值
    for optAttrVal in [0, 1]:
        subDataset = Dataset[Dataset[str(optAttr)] == optAttrVal]
        if len(subDataset) == 0:  # 为node加上一个分支，分支为叶子节点，叶子节点类别标记为Dataset中样本数最多的类
            leafNode = TreeNode(attrName="")
            leafNode.setLeaf(label=C)
            leafNodeTree = Tree(rootNode=leafNode)
            node.addSon(attrVal=optAttrVal, subTree=leafNodeTree)
        else:
            reducedAttributes=copy.deepcopy(Attributes)
            reducedAttributes.remove(optAttr)
            #import pdb;pdb.set_trace();
            sonTree = treeGeneration(Dataset=subDataset, Attributes=reducedAttributes)
            node.addSon(attrVal=optAttrVal, subTree=sonTree)
            

    tree = Tree(rootNode=node)
    return tree

# %%
# ===============================================================
#
#                         Construct Tree v2
#
# ===============================================================
def gini(Dataset):
    labels = list(set(Dataset['label']))
    nrow = float(len(Dataset))

    def ratioSqr(label):
        return (float(sum(Dataset['label'] == label)) / nrow) ** 2

    giniVal = 1.0 - sum(map(ratioSqr, labels))
    return giniVal


def giniIndex(Dataset, attrName):
    giniIndexVal = 0.0
    nrow = float(len(Dataset))

    subDataset = Dataset[Dataset[attrName] == 0]
    nrowSub = float(len(subDataset))
    giniIndexVal += gini(subDataset) * nrowSub

    subDataset = Dataset[Dataset[attrName] == 1]
    nrowSub = float(len(subDataset))
    giniIndexVal += gini(subDataset) * nrowSub

    return giniIndexVal / nrow


def attrSelection(Dataset, Attributes, cheatMode=False):
    if cheatMode == True:
        Dataset = Dataset.sample(frac=0.3)

    def fucktion(attr):
        return giniIndex(Dataset, str(attr))

    optAttr = min(Attributes, key=fucktion)
    return (optAttr,giniIndex(Dataset, str(optAttr)))

# =========================================================
# =========================================================

def identicalRows(df):
    for rowID in range(len(df) - 1):
        if not df.iloc[rowID, 1:].equals(df.iloc[rowID + 1, 1:]):
            return False
    return True


def treeGeneration(Dataset, Attributes):
    labels = train['label']

    # 1. 生成空节点node
    node = TreeNode(attrName="unset")
    # tree = Tree(rootNode=node)

    # 2. Boundary Case 1
    if len(set(labels)) == 1:  # 如果Dataset中的样本全属于同一类别C
        C = labels.iloc[0]
        node.sefLeaf(label=C)  # 将node标记成C类叶子节点
        tree = Tree(rootNode=node)
        return tree

    # 3. Boundary Case 2
    # 找到Dataset中样本数最多的类
    try:
        C = pd.Series.mode(labels)[0]
    except KeyError:
        C = labels.iloc[0]
    except IndexError:
        C = labels.iloc[0]

    if Attributes == [] or identicalRows(Dataset.iloc[:, Attributes]):  # 如果Attributes=∅,或者Dataset在Attributes的这几个属性上取值相同
        node.setLeaf(label=C)  # 将node标记成叶子节点，其类别是Dataset中样本数最多的类
        tree = Tree(rootNode=node)
        return tree

    # 3.5 pre剪枝 (myYY)
    if len(Dataset)<21:
        node.setLeaf(label=C)  # 将node标记成叶子节点，其类别是Dataset中样本数最多的类
        tree = Tree(rootNode=node)
        return tree

    # 4. 选择最优划分属性: optAttr
    t1=time.time()
    optAttr,giniCoef = attrSelection(Dataset, Attributes, cheatMode=False)
    t2=time.time()
    print("selected attr: %d,   size:%d, taking %f secs" % (optAttr, len(Dataset), t2-t1))
    sys.stdout.flush()
    node.setAttr(str(optAttr))
    
    # 4.5 剪枝 太小的基尼系数直接标成叶子节点，已经比较纯了
    if giniCoef< 0.1:
        node.setLeaf(label=C)  # 将node标记成叶子节点，其类别是Dataset中样本数最多的类
        tree = Tree(rootNode=node)
        return tree

    # 5. 为optAttr属性的每一个值
    for optAttrVal in [0, 1]:
        subDataset = Dataset[Dataset[str(optAttr)] == optAttrVal]
        if len(subDataset) == 0:  # 为node加上一个分支，分支为叶子节点，叶子节点类别标记为Dataset中样本数最多的类
            leafNode = TreeNode(attrName="")
            leafNode.setLeaf(label=C)
            leafNodeTree = Tree(rootNode=leafNode)
            node.addSon(attrVal=optAttrVal, subTree=leafNodeTree)
        else:
            reducedAttributes=copy.deepcopy(Attributes)
            reducedAttributes.remove(optAttr)
            #import pdb;pdb.set_trace();
            sonTree = treeGeneration(Dataset=subDataset, Attributes=reducedAttributes)
            node.addSon(attrVal=optAttrVal, subTree=sonTree)
            

    tree = Tree(rootNode=node)
    return tree

# %%
# ===============================================================
#
#                      Train Data and Test Data
#
# ===============================================================
import sys
import copy
import time
import scipy.io
rawData = scipy.io.loadmat('Sogou_data/Sogou_webpage.mat')
docLabels   = rawData['doclabel']
wordVectors = rawData['wordMat']
docCnt=len(docLabels)
wordCnt =wordVectors.shape[1]


import numpy as np
import pandas as pd
df_wordVectors = pd.DataFrame(data=docLabels, columns=['label'])
df_docLabels   = pd.DataFrame(wordVectors,columns=[str(x) for x in range(1,1+wordCnt)])
cleanData = pd.concat([df_wordVectors, df_docLabels], axis=1)


labelCnt =len(set(cleanData['label']))


train = cleanData.sample(frac=0.3)
test =  cleanData.drop(train.index).sample(frac=0.3)

print("train size=%d"%len(train))
print("test size=%d"%len(test))
# Out:
# train size=4320
# test size=3024

# %%
# ===============================================================
#
#                         Train Model
#
# ===============================================================

trainBegin=time.time()
dct1=treeGeneration(Dataset=train, Attributes=list(range(1,1+1200)))
trainEnd - time.time()
print("train finished, taking %f secs"%(trainEnd-trainBegin))
# Out:
# selected attr: 368,   size:4320, taking 56.759882 secs
# selected attr: 473,   size:3892, taking 51.271778 secs
# selected attr: 263,   size:3554, taking 46.829468 secs
# selected attr: 384,   size:3165, taking 41.816650 secs
# selected attr: 963,   size:2813, taking 37.578383 secs
# selected attr: 1114,   size:2563, taking 34.373369 secs
# selected attr: 966,   size:2375, taking 31.985517 secs
# selected attr: 1000,   size:2157, taking 29.296367 secs
# selected attr: 1005,   size:1972, taking 26.981720 secs
# selected attr: 1066,   size:1844, taking 25.375448 secs
# selected attr: 219,   size:1683, taking 23.409224 secs
# selected attr: 13,   size:1513, taking 21.264023 secs
# selected attr: 455,   size:1098, taking 16.051664 secs
# selected attr: 1198,   size:998, taking 14.823905 secs
# selected attr: 557,   size:947, taking 14.126046 secs
# selected attr: 120,   size:892, taking 13.217130 secs
# selected attr: 307,   size:741, taking 11.260431 secs
# selected attr: 893,   size:674, taking 10.449273 secs
# selected attr: 51,   size:629, taking 9.912848 secs
# selected attr: 1077,   size:540, taking 8.785852 secs
# selected attr: 99,   size:516, taking 8.499090 secs
# selected attr: 1101,   size:415, taking 7.286369 secs
# selected attr: 752,   size:387, taking 6.912375 secs
# selected attr: 634,   size:360, taking 6.593030 secs
# selected attr: 369,   size:347, taking 6.429088 secs
# selected attr: 400,   size:333, taking 6.225547 secs
# selected attr: 516,   size:292, taking 5.722209 secs
# selected attr: 933,   size:270, taking 5.452993 secs
# selected attr: 224,   size:258, taking 5.318636 secs
# selected attr: 959,   size:233, taking 4.958679 secs
# selected attr: 1,   size:207, taking 4.666904 secs
# selected attr: 230,   size:141, taking 3.671759 secs
# selected attr: 930,   size:136, taking 3.608604 secs
# selected attr: 1093,   size:129, taking 3.512837 secs
# selected attr: 555,   size:125, taking 3.460197 secs
# selected attr: 339,   size:121, taking 3.405552 secs
# selected attr: 1159,   size:111, taking 3.246128 secs
# selected attr: 53,   size:107, taking 3.196000 secs
# selected attr: 449,   size:96, taking 3.025541 secs
# selected attr: 209,   size:91, taking 2.954352 secs
# selected attr: 73,   size:87, taking 2.947333 secs
# selected attr: 398,   size:83, taking 2.823003 secs
# selected attr: 448,   size:77, taking 2.737777 secs
# selected attr: 647,   size:74, taking 2.714723 secs
# selected attr: 1002,   size:72, taking 2.662080 secs
# selected attr: 26,   size:70, taking 2.627484 secs
# selected attr: 1091,   size:65, taking 2.385841 secs
# selected attr: 892,   size:63, taking 2.175285 secs
# selected attr: 87,   size:61, taking 1.985286 secs
# selected attr: 181,   size:59, taking 1.787752 secs
# selected attr: 103,   size:57, taking 1.774216 secs
# selected attr: 256,   size:56, taking 1.590727 secs
# selected attr: 826,   size:55, taking 1.418771 secs
# selected attr: 1129,   size:54, taking 1.317000 secs
# selected attr: 1094,   size:53, taking 1.245811 secs
# selected attr: 2,   size:51, taking 1.065331 secs
# selected attr: 3,   size:46, taking 1.047290 secs
# selected attr: 4,   size:43, taking 1.032754 secs
# selected attr: 5,   size:27, taking 0.983115 secs
# selected attr: 6,   size:26, taking 0.982110 secs
# selected attr: 7,   size:23, taking 0.963560 secs
# selected attr: 8,   size:23, taking 0.962561 secs
# selected attr: 9,   size:23, taking 0.957545 secs
# selected attr: 10,   size:23, taking 0.962059 secs
# selected attr: 11,   size:23, taking 0.954036 secs
# selected attr: 12,   size:23, taking 0.963561 secs
# selected attr: 14,   size:23, taking 0.960052 secs
# selected attr: 15,   size:23, taking 0.957545 secs
# selected attr: 16,   size:23, taking 0.953534 secs
# selected attr: 17,   size:23, taking 1.041272 secs
# selected attr: 18,   size:23, taking 0.953534 secs
# selected attr: 19,   size:22, taking 0.947017 secs
# selected attr: 20,   size:22, taking 0.949022 secs
# selected attr: 21,   size:22, taking 0.950025 secs
# selected attr: 22,   size:22, taking 0.946515 secs
# selected attr: 23,   size:22, taking 0.942506 secs
# selected attr: 24,   size:22, taking 0.941005 secs
# selected attr: 25,   size:22, taking 0.943508 secs
# selected attr: 27,   size:22, taking 0.943006 secs
# selected attr: 28,   size:22, taking 0.936990 secs
# selected attr: 29,   size:22, taking 0.935486 secs
# selected attr: 30,   size:22, taking 0.940502 secs
# selected attr: 31,   size:22, taking 0.939999 secs
# selected attr: 32,   size:22, taking 0.934985 secs
# selected attr: 33,   size:22, taking 0.930974 secs
# selected attr: 34,   size:22, taking 0.937993 secs
# selected attr: 35,   size:21, taking 0.932478 secs
# selected attr: 36,   size:21, taking 0.926964 secs
# selected attr: 37,   size:21, taking 0.927465 secs
# selected attr: 38,   size:21, taking 0.925468 secs
# selected attr: 39,   size:21, taking 1.041268 secs
# selected attr: 40,   size:21, taking 0.924958 secs
# selected attr: 41,   size:21, taking 0.929471 secs
# selected attr: 42,   size:21, taking 0.928471 secs
# selected attr: 260,   size:66, taking 2.643028 secs
# selected attr: 236,   size:56, taking 2.509671 secs
# selected attr: 46,   size:53, taking 2.450514 secs
# selected attr: 164,   size:45, taking 2.323175 secs
# selected attr: 167,   size:42, taking 2.260508 secs
# selected attr: 592,   size:37, taking 2.190321 secs
# selected attr: 410,   size:32, taking 2.108611 secs
# selected attr: 57,   size:29, taking 2.053970 secs
# selected attr: 128,   size:21, taking 1.688490 secs
# selected attr: 165,   size:26, taking 1.579197 secs
# selected attr: 32,   size:23, taking 1.413758 secs
# selected attr: 7,   size:25, taking 1.651388 secs
# selected attr: 702,   size:22, taking 1.332542 secs
# selected attr: 431,   size:41, taking 2.221907 secs
# selected attr: 56,   size:35, taking 2.139695 secs
# selected attr: 5,   size:28, taking 2.043432 secs
# selected attr: 1,   size:27, taking 1.027230 secs
# selected attr: 2,   size:23, taking 1.010686 secs
# selected attr: 3,   size:23, taking 1.004169 secs
# selected attr: 4,   size:23, taking 1.002665 secs
# selected attr: 178,   size:28, taking 1.747645 secs
# selected attr: 29,   size:23, taking 1.429299 secs
# selected attr: 1,   size:22, taking 1.022718 secs
# selected attr: 24,   size:101, taking 3.127312 secs
# selected attr: 411,   size:65, taking 2.396871 secs
# selected attr: 774,   size:59, taking 2.334206 secs
# selected attr: 196,   size:55, taking 2.275047 secs
# selected attr: 3,   size:45, taking 2.072010 secs
# selected attr: 77,   size:25, taking 1.443343 secs
# selected attr: 4,   size:23, taking 1.167603 secs
# selected attr: 1,   size:22, taking 1.099923 secs
# selected attr: 798,   size:36, taking 2.249480 secs
# selected attr: 608,   size:32, taking 2.065490 secs
# selected attr: 60,   size:30, taking 1.875997 secs
# selected attr: 14,   size:24, taking 1.177128 secs
# selected attr: 1,   size:23, taking 1.032747 secs
# selected attr: 992,   size:89, taking 2.960869 secs
# selected attr: 344,   size:76, taking 2.784401 secs
# selected attr: 458,   size:65, taking 2.603921 secs
# selected attr: 576,   size:58, taking 2.506662 secs
# selected attr: 112,   size:53, taking 2.506663 secs
# selected attr: 192,   size:43, taking 2.096572 secs
# selected attr: 284,   size:39, taking 2.010343 secs
# selected attr: 56,   size:37, taking 1.836387 secs
# selected attr: 173,   size:31, taking 1.770712 secs
# selected attr: 480,   size:28, taking 1.467904 secs
# selected attr: 163,   size:26, taking 1.183649 secs
# selected attr: 1,   size:25, taking 1.038761 secs
# selected attr: 618,   size:45, taking 2.088051 secs
# selected attr: 914,   size:41, taking 1.818333 secs
# selected attr: 96,   size:38, taking 1.395710 secs
# selected attr: 109,   size:37, taking 1.235787 secs
# selected attr: 1,   size:36, taking 1.080372 secs
# selected attr: 2,   size:26, taking 1.046281 secs
# selected attr: 3,   size:23, taking 1.024224 secs
# selected attr: 918,   size:67, taking 2.691157 secs
# selected attr: 819,   size:63, taking 2.670099 secs
# selected attr: 19,   size:59, taking 2.529724 secs
# selected attr: 490,   size:52, taking 2.234941 secs
# selected attr: 284,   size:46, taking 2.071506 secs
# selected attr: 188,   size:44, taking 1.745640 secs
# selected attr: 383,   size:42, taking 1.590728 secs
# selected attr: 602,   size:41, taking 1.432307 secs
# selected attr: 166,   size:40, taking 1.273394 secs
# selected attr: 214,   size:39, taking 1.307475 secs
# selected attr: 1,   size:38, taking 1.101932 secs
# selected attr: 2,   size:27, taking 1.065833 secs
# selected attr: 1093,   size:151, taking 3.701344 secs
# selected attr: 768,   size:142, taking 3.581021 secs
# selected attr: 51,   size:122, taking 3.351909 secs
# selected attr: 124,   size:106, taking 3.134331 secs
# selected attr: 1091,   size:87, taking 2.811974 secs
# selected attr: 239,   size:83, taking 2.750310 secs
# selected attr: 563,   size:75, taking 2.694161 secs
# selected attr: 377,   size:72, taking 2.586876 secs
# selected attr: 636,   size:67, taking 2.505679 secs
# selected attr: 214,   size:64, taking 2.459044 secs
# selected attr: 73,   size:59, taking 2.214388 secs
# selected attr: 743,   size:54, taking 2.142703 secs
# selected attr: 292,   size:52, taking 2.131666 secs
# selected attr: 1164,   size:50, taking 1.798287 secs
# selected attr: 920,   size:48, taking 1.518536 secs
# selected attr: 121,   size:46, taking 1.432315 secs

# %%
# ===============================================================
#
#                         Predictor Definition
#
# ===============================================================
def predict(decisionTree, Dataset):
    predicted= []
    for rowID in range(len(Dataset)):
        DataItem = Dataset.iloc[rowID,:]
        currNode = decisionTree.root
        while not currNode.isLeaf:
            judgeAttrName=currNode.getAttr()
            judgeVal = DataItem[judgeAttrName]
            currNode = currNode.getSonByAttrVal(judgeVal).root
        predicted.append(currNode.leafLabel)
        print(rowID)
        sys.stdout.flush()
    return predicted
# Out:
# True

# %%
res=predict(dct1, test)

# %%
correct=list(test['label'].values)

# %%
sum([res[labelID]==correct[labelID] for labelID in range(len(res))])/len(correct)

# %%
# Out:
# 0.10922403381642512

# %%
len(train[train['label']==10])
# Out:
# 0

# %%
# Out:
# 1
# attr1 = 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-c8bb7c08fc30> in <module>()
#       4 judgeVal=DataItem[judgeAttrName]
#       5 print("attr%s = %d"%(judgeAttrName, judgeVal))
# ----> 6 currNode = currNode.getSonByAttrVal(judgeVal).root
#
# <ipython-input-11-5801461d0f67> in getSonByAttrVal(self, attrVal)
#      19
#      20     def getSonByAttrVal(self, attrVal):
# ---> 21         return self.son[attrVal]
#      22
#      23     def getCurrentAttrDivision(self):
#
# KeyError: 0

# %%
# Out:
# c:\program files\python35\lib\site-packages\pandas\core\ops.py:792: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-482ed9ef4984> in <module>()
# ----> 1 train[train['label']=='1']
#
# c:\program files\python35\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# c:\program files\python35\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     792                     result = getattr(x, name)(y)
#     793                 if result is NotImplemented:
# --> 794                     raise TypeError("invalid type comparison")
#     795             except AttributeError:
#     796                 result = op(x, y)
#
# TypeError: invalid type comparison
